# %%
# %pylab
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
import sklearn
import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
image_index=2
plt.imshow(x_train[image_index], cmap='Greys')
plt.title(y_train[image_index])
None

# %%
image_index=0
plt.imshow(x_test[image_index], cmap='Greys')
plt.title(y_test[image_index])
None

# %%
nearest=np.argsort(((x_test[image_index]-x_train)**2).sum(-1).sum(-1))

# %%
nearest[:10]
# Out:
# array([52124, 14866, 58836, 53187, 51279, 13650, 53510, 57979, 37384,
#        39544])

# %%
image_index=nearest[0]
plt.imshow(x_train[image_index], cmap='Greys')
plt.title(y_train[image_index])
None

# %%
y_train[nearest[:10]]
# Out:
# array([7, 7, 7, 1, 7, 4, 7, 1, 1, 7], dtype=uint8)

# %%
print len(x_train)
print len(x_test)
# Out:
# 60000
# 10000

# %%
import sklearn.neighbors

# %%
knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=20)
knn.fit(x_train[:30000].reshape(-1,28*28), y_train[:30000])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#            weights='uniform')

# %%
(knn.predict(x_test[:200].reshape(-1,28*28))==y_test[:200]).mean()
# Out:
# 0.965
